# %%
# printing hello world
print("Hello World")
# Out:
# Hello World

# %%
# Data types 
type(1)
# Out:
# int

# %%
type(2.4)
# Out:
# float

# %%
1 + 2
# Out:
# 3

# %%
4 - 1
# Out:
# 3

# %%
type(True)
# Out:
# bool

# %%
type('Hello World')
# Out:
# str

# %%
# Variables 

message_1 = 'I am learning Python'

message_2 = 'It is fun'

message_1 + ' ' + message_2
# Out:
# 'I am learning Python It is fun'

# %%
# List
countries = [ 'United States', 'India', 
            'China', 'Brazil' ]

countries
print( countries[0] )
print( countries[1] )
print( countries[2] )
print( countries[3] )
# Out:
# United States
# India
# China
# Brazil

# %%
# slicing

countries[0:3]
# Out:
# ['Spain', 'United States', 'India']

# %%
countries[1:]
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries[0:1]
# Out:
# ['Spain']

# %%
countries[:2]
# Out:
# ['Spain', 'United States']

# %%
# adding elements to a list using append

countries.append('Canada')
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
# adding elements to a list using insert
countries.insert(0, 'Spain')
countries

# %%
countries_2 = ['UK', 'Germany', 'Austria']

countries + countries
# Out:
# ['Spain',
#  'United States',
#  'India',
#  'China',
#  'Brazil',
#  'Canada',
#  'Spain',
#  'United States',
#  'India',
#  'China',
#  'Brazil',
#  'Canada']

# %%
nested_list = [ countries, countries_2 ]
nested_list
# Out:
# [['Spain', 'United States', 'India', 'China', 'Brazil', 'Canada'],
#  ['UK', 'Germany', 'Austria']]

# %%
# Removing elements from a list

countries.pop(0)
countries.remove('Brazil')
# Out:
# ['India', 'China', 'Brazil', 'Canada']

# %%
del countries[2]

# %%
countries
# Out:
# ['India', 'China', 'Canada']

# %%
# Sorting a list

numbers = [ 4, 3, 10, 7, 1, 2 ]

# %%
numbers
# Out:
# [1, 2, 3, 4, 7, 10]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %%
# Update an element in a list

numbers[0] = 1000
numbers
# Out:
# [1000, 7, 4, 3, 2, 1]

# %%
# Copying a list

countries = ['United States', 'India', 'China', 'Brazil']
new_list = countries[:]
new_list
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
new_list_2 = countries.copy()
new_list_2
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
# Dictionaries

my_data = {'name': 'Frank', 'age': 26}
my_data
# Out:
# {'name': 'Frank', 'age': 26}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Frank', 26])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Frank'), ('age', 26)])

# %%
# Adding another key to the dictionary

my_data['height'] = 1.7
my_data
# Out:
# {'name': 'Frank', 'age': 26, 'height': 1.7}

# %%
my_data.update({'height': 1.8})
my_data
# Out:
# {'name': 'Frank', 'age': 26, 'height': 1.8}

# %%
# Copying a dictionary

new_dict = my_data.copy()

new_dict
# Out:
# {'name': 'Frank', 'age': 26, 'height': 1.8}

# %%
# Removing a dictionary element 

my_data.pop('name')
my_data
# Out:
# {'age': 26, 'height': 1.8}

# %%
my_data
# Out:
# {'height': 1.8}

# %%
# Clearing all dictionary elements 

my_data.clear()
my_data
# Out:
# {}

# %%
# If Statement 

age = 12

if age >= 18:
    print("You're an adult")
elif age >= 13:
    print("You're a teenager")
else:
    print("You're a kid")
# Out:
# You're a kid

# %%
# For loop

for i, country in enumerate(countries):
    print(i)
    print(country)
# Out:
# 0
# United States
# 1
# India
# 2
# China
# 3
# Brazil

# %%
my_data = {'name':'Frank', 'age': 26}
my_data
# Out:
# {'name': 'Frank', 'age': 26}

# %%
for key, value in my_data.items():
    print(key)
    print(value)
# Out:
# name
# Frank
# age
# 26

# %%
# Functions

def sum_values(a, b):
    x = a + b
    return x

# %%
sum_values(1, 3)
# Out:
# 4

# %%
# Built-in functions
countries = ['United States', 'India', 'China', 'Brazil']
len(countries)
# Out:
# 4

# %%
max([10, 63, 81, 1, 99])
# Out:
# 99

# %%
min([10, 63, 81, 1, 99])
# Out:
# 1

# %%
type(countries)
# Out:
# list

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# Modules (OS)

import os
os.getcwd()
# Out:
# '/home/thecoderguru'

# %%
os.listdir()
# Out:
# ['.bash_logout',
#  '.bashrc',
#  '.config',
#  '.profile',
#  '.sommelierrc',
#  '.gnupg',
#  '.Xauthority',
#  'anaconda3',
#  '.conda',
#  '.bash_history',
#  '.local',
#  '.ipython',
#  '.jupyter',
#  '.ipynb_checkpoints',
#  'Example.ipynb']

# %%
os.makedirs("New Folder")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_1523/972085348.py in <module>
# ----> 1 os.makedirs("New Folder")
#
# ~/anaconda3/lib/python3.9/os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: 'New Folder'

# %%
os.listdir()
# Out:
# ['.bash_logout',
#  '.bashrc',
#  '.config',
#  '.profile',
#  '.sommelierrc',
#  '.gnupg',
#  '.Xauthority',
#  'anaconda3',
#  '.conda',
#  '.bash_history',
#  '.local',
#  '.ipython',
#  '.jupyter',
#  '.ipynb_checkpoints',
#  'Example.ipynb',
#  'New Folder']

# %%
# Pandas Introduction

import pandas as pd
import numpy as np

data = np.array([[1,4], [2,5], [3,6]])

# %%
# creating a dataframe

df = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns=['col1', 'col2'])
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
# creating an array with list shape
data = [[1,4], [2,5], [3,6]]

# %%
df_2 = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns=['col1', 'col2'])

# %%
# showing the dataframe

df_2
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
# creating a dataframe from a dictionary

states = ['California', 'Texas', 'Florida', 'New York']
population = [39613493, 29730311, 21944577, 19299981]

# %%
# storing lists within a dictionary

dict_states = {'States': states, 'Population': population}

# %%
# creating the dataframe

df_population = pd.DataFrame(dict_states)
df_population
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577
# 3    New York    19299981

# %%
# creating a dataframe from a csv file
import pandas as pd
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
# show first 5 rows in the dataframe

df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# show last 5 rows in the dataframe

df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# Show last n rows in a dataframe

df_exams.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
# getting access to the shape attribute

df_exams.shape
# Out:
# (1000, 8)

# %%
# display n rows

pd.set_option('display.max_rows', 1000)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
# getting access to the shape attribute

df_exams.shape
# Out:
# (1000, 8)

# %%
# getting access to the index attribute

df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# getting access to the column attribute

df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# data types of each column

df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
# Methods - Showing the first 5 columns

df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Showing the info of the dataframe

df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# describing basic statistics of the dataframe

df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# obtaining the length of the dataframe(number of columns)

len(df_exams)
# Out:
# 1000

# %%
# obtaining the highest index of the dataframe

max(df_exams.index)
# Out:
# 999

# %%
# obtaining the lowest index of the dataframe

min(df_exams.index)
# Out:
# 0

# %%
# obtaining the data type

type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
# rounding the values of the dataset

round(df_exams)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()

# select a column with [] (preferred way to select a column)

df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# check out the data type of a column

type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
# series, attributes and methods 

df_exams['gender'].index
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
# select a column with .

df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# select a column with . (pitfalls)

df_exams.math score

# %%
# select the same column using []

df_exams['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
# selecting 2 columns using [[]]

df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
# check out the datatype of the selection 

type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
# select two or more columns using [[]]

df_exams[['gender', 'math score', 'lunch', 'reading score']]
# Out:
#      gender  math score         lunch  reading score
# 0    female          72      standard             72
# 1    female          69      standard             90
# 2    female          90      standard             95
# 3      male          47  free/reduced             57
# 4      male          76      standard             78
# ..      ...         ...           ...            ...
# 995  female          88      standard             99
# 996    male          62  free/reduced             55
# 997  female          59  free/reduced             71
# 998  female          68      standard             78
# 999  female          77  free/reduced             86
#
# [1000 rows x 4 columns]

# %%
# adding a new column with a scalar value 

df_exams['language score'] = 25
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# adding a new column with an array and creating an array of 1000 elements 

import numpy as np
language_score = np.arange(0, 1000)

# %%
# length of the array

len(language_score)
# Out:
# 1000

# %%
# adding a new column to a dataframe with an array 

df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# create random integer numbers between 1 and 100

random_language = np.random.randint(1, 100, size=1000)
df_exams['language score'] = random_language
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# min value inclusive and high value exclusive

min(df_exams['language score'])
# Out:
# 1

# %%
max(df_exams['language score'])
# Out:
# 99

# %%
# create random float numbers between 1 and 100

np.random.uniform(1, 100, size=100)
# Out:
# array([49.92695409, 64.42954727, 24.86943517, 80.86163447, 32.71899205,
#        23.59661751, 53.47853027, 75.8611599 ,  6.85121533, 78.98305589,
#        23.28404039, 36.10368916, 71.51772534, 88.4250553 ,  9.41715914,
#        79.20306363, 60.89578017, 38.60706998,  4.30340631, 34.21489741,
#        63.17677468, 63.8157017 , 18.18965921, 66.10045425,  8.45962409,
#        59.7405158 , 61.06913489, 35.58749851,  2.04461316, 91.0357811 ,
#        68.25728225, 58.55744548, 32.69337087, 49.18728151, 45.58745504,
#        66.52628414, 68.57988638, 55.72824757, 38.32221006, 75.62235689,
#        85.78737912, 66.80374397, 42.07586242, 93.40682478, 53.51875495,
#        77.57130824,  1.23640405, 74.07421753, 89.97238231, 43.0079882 ,
#        29.89917757, 85.58976037, 77.68061606, 43.27066877, 39.91271533,
#        53.78507155, 78.72670131, 64.41232177, 45.57711561, 15.78975984,
#        38.52956792, 36.42140726, 20.37681866, 18.32266102, 41.16795143,
# ...

# %%
# Math operations in columns - select a column and calculate total sum

sum(df_exams['math score'])
df_exams['math score'].sum()
# Out:
# 66089

# %%
# count, mean , std, max and min 

df_exams['math score'].count()
df_exams['math score'].mean()
df_exams['math score'].std()
df_exams['math score'].max()
df_exams['math score'].min()
# Out:
# 0

# %%
# easier calculation with describe()

df_exams.describe()
# Out:
#        math score  reading score  writing score  language score
# count      1000.0         1000.0         1000.0          1000.0
# mean         66.0           69.0           68.0            51.0
# std          15.0           15.0           15.0            29.0
# min           0.0           17.0           10.0             1.0
# 25%          57.0           59.0           58.0            26.0
# 50%          66.0           70.0           69.0            50.0
# 75%          77.0           79.0           79.0            76.0
# max         100.0          100.0          100.0            99.0

# %%
# Operations in rows
import pandas as pd
df_exams = pd.read_csv('StudentsPerformance.csv')

df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
# Finding the average and assigning the result to a new column

df_exams['average'] = df_exams['math score'] + df_exams['reading score'] + df_exams['writing score'] / 3;
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# Rounding the average score in the dataframe

df_exams.round(2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  average
# ...

# %%
# Using the value_counts() method to count the gender elements by category 

df_exams['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# return the relative frequency ( divide all the values by the sum of values )

df_exams['gender'].value_counts(normalize=True)
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %%
# counting "parental level of education" elements by category

df_exams['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
# return the relative frequency and round to 2 decimals

df_exams['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: parental level of education, dtype: float64

# %%
# Sort a dataframe

df_exams.sort_values('math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# sort descending by one column 

df_exams.sort_values('reading score', ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 546  female        group A            some high school      standard
# 970  female        group D           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 566  female        group E           bachelor's degree  free/reduced
# 712  female        group D                some college      standard
# ..      ...            ...                         ...           ...
# 76     male        group E            some high school      standard
# 980  female        group B                 high school  free/reduced
# 596    male        group B                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# sort descending by multiple columns 

df_exams.sort_values(['writing score', 'reading score'], ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 458  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 980  female        group B                 high school  free/reduced
# 76     male        group E            some high school      standard
# 327    male        group A                some college  free/reduced
# 596    male        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# sort descending by multiple columns and update dataframe

df_exams.sort_values(['math score', 'reading score'], ascending=False, inplace=True)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# sort descending with a key function 

df_exams.sort_values('race/ethnicity', ascending=True, key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# using the pivot function in pandas

import pandas as pd
df_gdp = pd.read_csv('gdp.csv', encoding="latin-1")

# %%
# reshape the dataframe with .pivot()
df_gdp.pivot(index="year", columns="country", values="gdppc")
# Out:
# country  Afghanistan     Albania      Algeria      Angola  Argentina  \
# year
# 1880       585.46509   522.00000    819.18604   533.66669   1731.500
# 1890       635.93024   598.00000    923.37207   567.33331   2152.000
# 1900       686.39532   685.00000   1027.55810   601.00000   2756.000
# 1910       736.86047   780.00000   1131.74410   628.69232   3822.000
# 1920       731.75677   861.31250   1201.21620   682.62964   3473.000
# 1930       702.83783   929.57141   1255.81080   747.81482   4080.000
# 1940       673.91895   965.28571   1310.40540   813.00000   4161.000
# 1950       645.00000  1001.00000   1365.00000  1052.00000   4987.000
# 1960       739.00000  1451.00000   2088.00000  1253.00000   5559.000
# 1970       709.00000  2004.00000   2249.00000  1768.00000   7302.000
# 1980       690.00000  2347.00000   3152.00000   961.00000   8206.000
# 1990       604.00000  4557.40820  10238.88400  4806.43020  10833.503
# ...

# %%
# pivot_table() - read and show the dataset

df_sales = pd.read_excel("supermarket_sales.xlsx")
df_sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# make a pivot table and add an aggregate function 

df_sales.pivot_table(index="Gender", aggfunc="sum")
# Out:
#         Quantity  Rating    Tax 5%       Total  Unit price       cogs  \
# Gender
# Female      2869  3489.2  7994.425  167882.925    27687.24  159888.50
# Male        2641  3483.5  7384.944  155083.824    27984.89  147698.88
#
#         gross income  gross margin percentage
# Gender
# Female      7994.425              2385.714286
# Male        7384.944              2376.190476

# %%
# Make a pivot table, add an aggregate function and select some columns

df_sales.pivot_table(index="Gender", values=["Quantity", "Total"], aggfunc="sum")
# Out:
#         Quantity       Total
# Gender
# Female      2869  167882.925
# Male        2641  155083.824

# %%
# make a pivot tables that says how much male and female spend in each category

df_sales.pivot_table(index="Gender", columns="Product line", values="Total", aggfunc="sum")
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                    27102.0225            30437.400          33170.9175
# Male                      27235.5090            23868.495          22973.9265
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female               18560.9865          30036.8775         28574.7210
# Male                 30632.7525          23825.0355         26548.1055

# %%
# data visualization with pandas
import pandas as pd
df_population_raw = pd.read_csv('population_total.csv')
df_population_raw
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
# dropping null values 

df_population_raw.dropna(inplace=True)

# %%
# making a pivot table 

df_pivot = df_population_raw.pivot(index='year', columns='country', values='population')

# %%
# selecting some countries

df_pivot = df_pivot[['United States', 'India', 'China', 'Indonesia', 'Brazil']]

# %%
# Lineplot

df_pivot.plot(kind='line', xlabel='Year', ylabel='Population', title='Population (1955 - 2021)', figsize=(8,4))
# Out:
# <AxesSubplot:title={'center':'Population (1955 - 2021)'}, xlabel='Year', ylabel='Population'>

# %%
# Barplot - selecting only one year ( 2020 )

df_pivot_2020 = df_pivot[df_pivot.index.isin([2020])]

# %%
# Transpose dataframe from rows to columns or viceversa

df_pivot_2020 = df_pivot_2020.T

# %%
# making a barplot

df_pivot_2020.plot(kind='bar', color='orange', xlabel='Year', ylabel='Population', title='Population 2020')
# Out:
# <AxesSubplot:title={'center':'Population 2020'}, xlabel='Year', ylabel='Population'>

# %%
# selecting a few years


df_pivot_sample = df_pivot[df_pivot.index.isin([1980, 1990, 2000, 2010, 2020])]

# %%
# making grouped barplot

df_pivot_sample.plot(kind='bar', xlabel='Year', ylabel='Population')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Population'>

# %%
# Piechart - changing column name

df_pivot_2020.rename(columns={2020:'2020'}, inplace=True)

# %%
df_pivot_2020.plot(kind='pie', y='2020')
# Out:
# <AxesSubplot:ylabel='2020'>
